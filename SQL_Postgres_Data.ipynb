# %% [markdown]
# # Leveraging PostgreSQL in Data Science with Python and R
# <div style="font-size: 24px; padding: 10px 0 0 0;">PostgreSQL Schema Build</div>
#
# <div style="float:right"><img src="IMAGES/postgres_sql.jpeg" height="125" width="125"/></div>
#
# ## Resources: ##
# - <h3> PostgreSQL v10.0 </h3>
# - <h3> Linux Ubuntu 16.04, 64-bit </h3>

# %%
# %%html
# <style>.prompt{width: 100px; min-width: 0; visibility: collapse}</style>
# Out:
# <style>.prompt{width: 100px; min-width: 0; visibility: collapse}</style>

# %% [markdown]
# ## Load SQL Extension ##

# %%
# %load_ext sql

# %% [markdown]
# ## Connect to PostgreSQL ##

# %%
# %sql postgresql+psycopg2://ctadba:cta18!@10.0.0.220/cta
# Out:
# 'Connected: ctadba@cta'

# %% [markdown]
# ## Create Table Schema ##

# %%
-- BUS DATA
CREATE TABLE bus_routes (
   id SERIAL,
   route_id INTEGER PRIMARY KEY,
   route_name VARCHAR(255)
);

CREATE TABLE bus_rides (
   id SERIAL PRIMARY KEY,
   route_id INTEGER,
   ride_date_string VARCHAR(15),
   ride_date DATE,
   day_type VARCHAR(1),
   rides INTEGER,
   FOREIGN KEY (route_id) REFERENCES bus_routes (route_id)
);

CREATE TABLE bus_month (
   id SERIAL PRIMARY KEY,
   route_id INTEGER,
   route_name VARCHAR(255),
   month_start_string VARCHAR(15),
   avg_weekday_rides NUMERIC(10,2),
   avg_saturday_rides NUMERIC(10,2),
   avg_sunday_rides NUMERIC(10,2),
   month_total NUMERIC(10,2)
);


-- RAIL DATA
CREATE TABLE rail_stations (
   id SERIAL PRIMARY KEY,
   station_id INTEGER,
   station_name VARCHAR(255),
   rail_line VARCHAR(10),
   ada SMALLINT,
   direction VARCHAR(3),
   location VARCHAR(255) 
);

CREATE TABLE rail_rides (
   id SERIAL PRIMARY KEY,
   station_id INTEGER,
   station_name VARCHAR(255),
   ride_date_string VARCHAR(15),
   ride_date DATE,
   day_type VARCHAR(1),
   rides INTEGER,
   FOREIGN KEY (station_id) REFERENCES rail_stations (station_id)
);

CREATE TABLE rail_stops (
   id SERIAL PRIMARY KEY,
   stop_id INTEGER,
   direction_id VARCHAR(1),
   stop_name VARCHAR(255),
   station_name VARCHAR(255),
   station_descriptive_name VARCHAR(255),
   map_id INTEGER,
   ada VARCHAR(5),
   red VARCHAR(5),
   blue VARCHAR(5),
   green VARCHAR(5),
   brown VARCHAR(5),
   purple VARCHAR(5),
   purple_exp VARCHAR(5),
   yellow VARCHAR(5),
   pink VARCHAR(5),
   orange VARCHAR(5),
   location VARCHAR(255)
);

# %% [markdown]
# ## Load CSV Data ##

# %%
COPY bus_rides (route_id, ride_date_string, day_type, rides) FROM '/home/oem/Documents/Meekness/Postgres/CTA_-_Ridership_-_Bus_Routes_-_Daily_Totals_by_Route.csv' WITH CSV HEADER DELIMITER AS ',';

COPY bus_month (route, route_name, month_start_string, avg_weekday_rides, avg_saturday_rides, avg_sunday_rides, month_total) FROM '/home/oem/Documents/Meekness/Postgres/CTA_-_Ridership_-_Bus_Routes_-_Monthly_Day-Type_Averages___Totals.csv' WITH CSV HEADER DELIMITER AS ',';


COPY rail_rides (station_id, station_name, ride_date_string, day_type, rides) FROM '/home/oem/Documents/Meekness/Postgres/CTA_-_Ridership_-__L__Station_Entries_-_Daily_Totals.csv' WITH CSV HEADER DELIMITER AS ',';

COPY rail_stops (stop_id, direction_id, stop_name, station_name, station_descriptive_name, map_id, ada, red, blue, green, brown, purple, purple_exp, yellow, pink, orange, location) FROM '/home/oem/Documents/Meekness/Postgres/CTA_-_System_Information_-_List_of__L__Stops.csv' WITH CSV HEADER DELIMITER AS ',';

# %% [markdown]
# ## User-Defined Function: Median ##

# %%
# %%sql
#
# -- SOURCE: https://wiki.postgresql.org/wiki/Aggregate_Median
#
# CREATE OR REPLACE FUNCTION _final_median(NUMERIC[])
#    RETURNS NUMERIC AS
# $$
#    SELECT AVG(val)
#    FROM (
#      SELECT val
#      FROM unnest($1) val
#      ORDER BY 1
#      LIMIT  2 - MOD(array_upper($1, 1), 2)
#      OFFSET CEIL(array_upper($1, 1) / 2.0) - 1
#    ) sub;
# $$
# LANGUAGE 'sql' IMMUTABLE;
#
# CREATE AGGREGATE median(NUMERIC) (
#   SFUNC=array_append,
#   STYPE=NUMERIC[],
#   FINALFUNC=_final_median,
#   INITCOND='{}'
# );
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# Done.
# Done.
# []

# %% [markdown]
# ## Reshape Data (Wide to Long)

# %%
# %%sql
#
# SELECT map_id, station_name,
#        MAX(CASE
#                WHEN red = 'true' THEN 'red'
#                WHEN blue = 'true' THEN 'blue'
#                WHEN green = 'true' THEN 'green'
#                WHEN brown = 'true' THEN 'brown'
#                WHEN purple = 'true' THEN 'purple'
#                WHEN purple_exp = 'true' THEN 'purple_exp'
#                WHEN yellow = 'true' THEN 'yellow'
#                WHEN pink = 'true' THEN 'pink'
#                WHEN orange = 'true' THEN 'orange'
#                ELSE NULL
#            END) AS rail_line_calc,
#         MAX(CASE WHEN ada = 'true' THEN 1 ELSE 0 END) AS ada_calc,
#         MAX(CASE
#                 WHEN direction_id IN ('E', 'W') THEN 'E/W'
#                 WHEN direction_id IN ('N', 'S') THEN 'N/S'
#                 ELSE NULL
#             END) AS direction_calc,
#        location
# FROM rail_stops
# GROUP BY map_id, station_name, red, blue, green, brown, purple, purple_exp, yellow, pink, orange,
#          ada, direction_id, location
# LIMIT 20;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# 20 rows affected.
# [(40010, 'Austin', 'blue', 0, 'E/W', '(41.870851, -87.776812)'),
#  (40010, 'Austin', 'blue', 0, 'E/W', '(41.870851, -87.776812)'),
#  (40020, 'Harlem/Lake', 'green', 1, 'E/W', '(41.886848, -87.803176)'),
#  (40020, 'Harlem/Lake', 'green', 1, 'E/W', '(41.886848, -87.803176)'),
#  (40030, 'Pulaski', 'green', 1, 'E/W', '(41.885412, -87.725404)'),
#  (40030, 'Pulaski', 'green', 1, 'E/W', '(41.885412, -87.725404)'),
#  (40040, 'Quincy/Wells', 'purple_exp', 0, 'N/S', '(41.878723, -87.63374)'),
#  (40040, 'Quincy/Wells', 'brown', 0, 'N/S', '(41.878723, -87.63374)'),
#  (40050, 'Davis', 'purple', 1, 'N/S', '(42.04771, -87.683543)'),
#  (40050, 'Davis', 'purple', 1, 'N/S', '(42.04771, -87.683543)'),
#  (40060, 'Belmont', 'blue', 0, 'N/S', '(41.938132, -87.712359)'),
#  (40060, 'Belmont', 'blue', 0, 'N/S', '(41.938132, -87.712359)'),
#  (40070, 'Jackson', 'blue', 1, 'N/S', '(41.878183, -87.629296)'),
#  (40070, 'Jackson', 'blue', 1, 'N/S', '(41.878183, -87.629296)'),
#  (40080, 'Sheridan', None, 0, 'N/S', '(41.953775, -87.654929)'),
#  (40080, 'Sheridan', None, 0, 'N/S', '(41.953775, -87.654929)'),
#  (40080, 'Sheridan', 'red', 0, 'N/S', '(41.953775, -87.654929)'),
#  (40080, 'Sheridan', 'red', 0, 'N/S', '(41.953775, -87.654929)'),
#  (40090, 'Damen', 'brown', 1, 'N/S', '(41.966286, -87.678639)'),
#  (40090, 'Damen', 'brown', 1, 'N/S', '(41.966286, -87.678639)')]

# %%
# %%sql
#
# WITH cte AS
#   (SELECT map_id, station_name, direction_id, ada, location,
#        unnest(array['red', 'blue', 'green', 'brown', 'purple',
#                     'purple_exp', 'orange', 'pink', 'yellow']) AS colname,
#        unnest(array[red, blue, green, brown, purple, purple_exp,
#                     orange, pink, yellow]) AS value
#    FROM rail_stops)
#
# SELECT map_id as station_id, station_name, colname as rail_line,
#        MAX(CASE WHEN ada = 'true' THEN 1 ELSE 0 END) AS ada,
#        STRING_AGG(direction_id, ' | ') AS direction, location
# FROM cte
# WHERE value = 'true'
# GROUP BY map_id, station_name, colname, location
# LIMIT 20;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# 25 rows affected.
# [(40010, 'Austin', 'blue', 0, 'W | E', '(41.870851, -87.776812)'),
#  (40020, 'Harlem/Lake', 'green', 1, 'E | W', '(41.886848, -87.803176)'),
#  (40030, 'Pulaski', 'green', 1, 'W | E', '(41.885412, -87.725404)'),
#  (40040, 'Quincy/Wells', 'brown', 0, 'S', '(41.878723, -87.63374)'),
#  (40040, 'Quincy/Wells', 'orange', 0, 'N', '(41.878723, -87.63374)'),
#  (40040, 'Quincy/Wells', 'pink', 0, 'N', '(41.878723, -87.63374)'),
#  (40040, 'Quincy/Wells', 'purple_exp', 0, 'N', '(41.878723, -87.63374)'),
#  (40050, 'Davis', 'purple', 1, 'S | N', '(42.04771, -87.683543)'),
#  (40050, 'Davis', 'purple_exp', 1, 'S | N', '(42.04771, -87.683543)'),
#  (40060, 'Belmont', 'blue', 0, 'N | S', '(41.938132, -87.712359)'),
#  (40070, 'Jackson', 'blue', 1, 'S | N', '(41.878183, -87.629296)'),
#  (40080, 'Sheridan', 'red', 0, 'N | S', '(41.953775, -87.654929)'),
#  (40090, 'Damen', 'brown', 1, 'N | S', '(41.966286, -87.678639)'),
#  (40100, 'Morse', 'red', 0, 'N | S', '(42.008362, -87.665909)'),
#  (40120, '35th/Archer', 'orange', 1, 'S | N', '(41.829353, -87.680622)'),
#  (40130, '51st', 'green', 1, 'N | S', '(41.80209, -87.618487)'),
#  (40140, 'Dempster-Skokie', 'yellow', 1, 'N | S', '(42.038951, -87.751919)'),
#  (40150, 'Pulaski', 'pink', 1, 'W | E', '(41.853732, -87.724311)'),
#  (40160, 'LaSalle/Van Buren', 'brown', 0, 'E', '(41.8768, -87.631739)'),
#  (40160, 'LaSalle/Van Buren', 'orange', 0, 'W', '(41.8768, -87.631739)'),
#  (40160, 'LaSalle/Van Buren', 'pink', 0, 'W', '(41.8768, -87.631739)'),
#  (40160, 'LaSalle/Van Buren', 'purple_exp', 0, 'W', '(41.8768, -87.631739)'),
#  (40170, 'Ashland', 'green', 1, 'E | W', '(41.885269, -87.666969)'),
#  (40170, 'Ashland', 'pink', 1, 'W | E', '(41.885269, -87.666969)'),
#  (40180, 'Oak Park', 'blue', 0, 'W | E', '(41.872108, -87.791602)')]

# %% [markdown]
# ## Right Hand Side (RHS) Schema

# %%
-- SOURCE: St. Louis Federal Reserve Bank
CREATE TABLE unemployment_rates (
   ID SERIAL PRIMARY KEY,
   ue_date DATE UNIQUE NOT NULL,
   ue_rate NUMERIC(10,4)
);


-- SOURCE: U.S. DEPT OF ENERGY: EIA
CREATE TABLE gas_prices (
   ID SERIAL PRIMARY KEY,
   gas_date DATE UNIQUE NOT NULL,
   gas_price NUMERIC(10,4)
);


-- SOURCE: U.S. NOAA
CREATE TABLE weather_data (
   ID SERIAL PRIMARY KEY,
   weather_date DATE UNIQUE NOT NULL,
   max_temp INTEGER,
   min_temp INTEGER,
   avg_temp NUMERIC(10,4),
   departure_temp NUMERIC(10,4),
   hdd INTEGER,
   cdd INTEGER,
   precipitation NUMERIC(10,4),
   new_snow NUMERIC(10,4),
   snow_depth NUMERIC(10,4)
);

# %% [markdown]
# ## Load Data

# %%
COPY unemployment_rates (ue_date, ue_rate) FROM '/home/oem/Documents/Meekness/Postgres/Chicago_Unemployment_Rates.csv' WITH CSV HEADER DELIMITER AS ',';

COPY gas_prices (gas_date, gas_price) FROM '/home/oem/Documents/Meekness/Postgres/US_Gas_Prices.csv' WITH CSV HEADER DELIMITER AS ',';

COPY  weather_data (weather_date, max_temp, min_temp, avg_temp, departure_temp, hdd, cdd, precipitation, new_snow, snow_depth) FROM '/home/oem/Documents/Meekness/Postgres/Chicago_Weather_Data.csv' WITH CSV HEADER DELIMITER AS ',';

# %% [markdown]
# ## Bus Ridership Regression Model: Materialized View

# %%
# %%sql
#
# CREATE MATERIALIZED VIEW Bus_Model_Data AS
#     SELECT b.id, b.route_id, b.ride_date, b.day_type, b.rides, r.route_name,
#            CASE
#                WHEN b.normalized_date BETWEEN '2099-01-01' AND '2099-03-19' THEN 'winter'
#                WHEN b.normalized_date BETWEEN '2099-03-20' AND '2099-06-19' THEN 'spring'
#                WHEN b.normalized_date BETWEEN '2099-06-20' AND '2099-09-19' THEN 'summer'
#                WHEN b.normalized_date BETWEEN '2099-09-20' AND '2099-12-19' THEN 'fall'
#                WHEN b.normalized_date BETWEEN '2099-12-20' AND '2099-12-31' THEN 'winter'
#                ELSE NULL
#            END As season,
#            ue.ue_rate, g.gas_price, w.avg_temp, w.precipitation, w.snow_depth
#     FROM
#      (
#       SELECT id, route_id, day_type, rides, ride_date,
#              ride_date + (2099 - date_part('year', ride_date)  ||' year')::interval as normalized_date
#       FROM bus_rides
#      ) b
#     INNER JOIN bus_routes r ON b.route_id = r.route_id
#     INNER JOIN unemployment_rates ue ON ue.ue_date = b.ride_date
#     INNER JOIN gas_prices g ON g.gas_date = b.ride_date
#     INNER JOIN weather_data w ON w.weather_date = b.ride_date
#     ORDER BY b.ride_date, NULLIF(regexp_replace(b.route_id, '\D', '', 'g'), '')::int;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# 781580 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Bus_Model_Data LIMIT 20;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# 20 rows affected.
# [(76, '3', datetime.date(2001, 1, 1), 'U', 7354, 'King Drive', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (77, '4', datetime.date(2001, 1, 1), 'U', 9288, 'Cottage Grove', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (78, '6', datetime.date(2001, 1, 1), 'U', 6048, 'Jackson Park Express', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (79, '8', datetime.date(2001, 1, 1), 'U', 6309, 'Halsted', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (157, '8A', datetime.date(2001, 1, 1), 'U', 1008, 'South Halsted', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (80, '9', datetime.date(2001, 1, 1), 'U', 11207, 'Ashland', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (81, '10', datetime.date(2001, 1, 1), 'U', 385, 'Museum of S & I', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (82, '11', datetime.date(2001, 1, 1), 'U', 610, 'Lincoln', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (83, '12', datetime.date(2001, 1, 1), 'U', 3678, 'Roosevelt', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (84, '18', datetime.date(2001, 1, 1), 'U', 375, '16th/18th', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (85, '20', datetime.date(2001, 1, 1), 'U', 7096, 'Madison', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (160, 'X21', datetime.date(2001, 1, 1), 'U', 723, 'Cermak Express', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (86, '21', datetime.date(2001, 1, 1), 'U', 3454, 'Cermak', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (87, '22', datetime.date(2001, 1, 1), 'U', 7877, 'Clark', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (88, '27', datetime.date(2001, 1, 1), 'U', 1903, 'South Deering', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (89, '28', datetime.date(2001, 1, 1), 'U', 5462, 'Stony Island', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (90, '29', datetime.date(2001, 1, 1), 'U', 9303, 'State', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (91, '30', datetime.date(2001, 1, 1), 'U', 600, 'South Chicago', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (92, '34', datetime.date(2001, 1, 1), 'U', 3541, 'South Michigan', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (93, '35', datetime.date(2001, 1, 1), 'U', 1526, '31st/35th', 'winter', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000'))]

# %%
# %%sql
#
# REFRESH MATERIALIZED VIEW Bus_Model_Data;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# Done.
# []

# %% [markdown]
# ## Rail Ridership Regression Model: Materialized View

# %%
# %%sql
#
# CREATE MATERIALIZED VIEW Rail_Model_Data AS
#     SELECT r.id, r.station_id, r.station_name, r.ride_date, r.day_type, r.rides AS raw,
#           (r.rides / COUNT(*) OVER(PARTITION BY r.station_id, r.ride_date)) AS rides,
#           CASE
#                WHEN r.normalized_date BETWEEN '2099-01-01' AND '2099-03-19' THEN 'winter'
#                WHEN r.normalized_date BETWEEN '2099-03-20' AND '2099-06-19' THEN 'spring'
#                WHEN r.normalized_date BETWEEN '2099-06-20' AND '2099-09-19' THEN 'summer'
#                WHEN r.normalized_date BETWEEN '2099-09-20' AND '2099-12-19' THEN 'fall'
#                WHEN r.normalized_date BETWEEN '2099-12-20' AND '2099-12-31' THEN 'winter'
#                ELSE NULL
#            END As season,
#            REPLACE(REPLACE((regexp_split_to_array(s.location, '\s+'))[1], ',', ''), '(', '')::numeric AS latitude,
#            REPLACE((regexp_split_to_array(s.location, '\s+'))[2], ')', '')::numeric AS longitude,
#            s.rail_line, s.ada, s.direction,
#            ue.ue_rate, g.gas_price, w.avg_temp, w.precipitation, w.snow_depth
#     FROM
#        (
#         SELECT id, station_id, station_name, day_type, rides, ride_date,
#                ride_date + (2099 - date_part('year', ride_date)  ||' year')::interval as normalized_date
#         FROM rail_rides
#        )r
#     INNER JOIN rail_stations s ON s.station_id = r.station_id
#     INNER JOIN unemployment_rates ue ON ue.ue_date = r.ride_date
#     INNER JOIN gas_prices g ON g.gas_date = r.ride_date
#     INNER JOIN weather_data w ON w.weather_date = r.ride_date
#     ORDER BY r.ride_date, r.station_id;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# 1230600 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Rail_Model_Data LIMIT 20;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
# 20 rows affected.
# [(1, 40010, 'Austin-Forest Park', datetime.date(2001, 1, 1), 'U', 290, 290, 'winter', Decimal('41.870851'), Decimal('-87.776812'), 'blue', 0, 'W | E', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (2, 40020, 'Harlem-Lake', datetime.date(2001, 1, 1), 'U', 633, 633, 'winter', Decimal('41.886848'), Decimal('-87.803176'), 'green', 1, 'E | W', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (3, 40030, 'Pulaski-Lake', datetime.date(2001, 1, 1), 'U', 483, 483, 'winter', Decimal('41.885412'), Decimal('-87.725404'), 'green', 1, 'W | E', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (4, 40040, 'Quincy/Wells', datetime.date(2001, 1, 1), 'U', 374, 93, 'winter', Decimal('41.878723'), Decimal('-87.63374'), 'brown', 0, 'S', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (4, 40040, 'Quincy/Wells', datetime.date(2001, 1, 1), 'U', 374, 93, 'winter', Decimal('41.878723'), Decimal('-87.63374'), 'orange', 0, 'N', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (4, 40040, 'Quincy/Wells', datetime.date(2001, 1, 1), 'U', 374, 93, 'winter', Decimal('41.878723'), Decimal('-87.63374'), 'pink', 0, 'N', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (4, 40040, 'Quincy/Wells', datetime.date(2001, 1, 1), 'U', 374, 93, 'winter', Decimal('41.878723'), Decimal('-87.63374'), 'purple_exp', 0, 'N', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (5, 40050, 'Davis', datetime.date(2001, 1, 1), 'U', 804, 402, 'winter', Decimal('42.04771'), Decimal('-87.683543'), 'purple_exp', 1, 'S | N', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (5, 40050, 'Davis', datetime.date(2001, 1, 1), 'U', 804, 402, 'winter', Decimal('42.04771'), Decimal('-87.683543'), 'purple', 1, 'S | N', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (6, 40060, "Belmont-O'Hare", datetime.date(2001, 1, 1), 'U', 1165, 1165, 'winter', Decimal('41.938132'), Decimal('-87.712359'), 'blue', 0, 'N | S', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (7, 40070, 'Jackson/Dearborn', datetime.date(2001, 1, 1), 'U', 649, 649, 'winter', Decimal('41.878183'), Decimal('-87.629296'), 'blue', 1, 'S | N', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (8, 40080, 'Sheridan', datetime.date(2001, 1, 1), 'U', 1116, 1116, 'winter', Decimal('41.953775'), Decimal('-87.654929'), 'red', 0, 'N | S', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (9, 40090, 'Damen-Brown', datetime.date(2001, 1, 1), 'U', 411, 411, 'winter', Decimal('41.966286'), Decimal('-87.678639'), 'brown', 1, 'N | S', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (10, 40100, 'Morse', datetime.date(2001, 1, 1), 'U', 1698, 1698, 'winter', Decimal('42.008362'), Decimal('-87.665909'), 'red', 0, 'N | S', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (11, 40120, '35th/Archer', datetime.date(2001, 1, 1), 'U', 318, 318, 'winter', Decimal('41.829353'), Decimal('-87.680622'), 'orange', 1, 'S | N', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (12, 40130, '51st', datetime.date(2001, 1, 1), 'U', 364, 364, 'winter', Decimal('41.80209'), Decimal('-87.618487'), 'green', 1, 'N | S', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (13, 40140, 'Skokie', datetime.date(2001, 1, 1), 'U', 0, 0, 'winter', Decimal('42.038951'), Decimal('-87.751919'), 'yellow', 1, 'N | S', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (14, 40150, 'Pulaski-Cermak', datetime.date(2001, 1, 1), 'U', 0, 0, 'winter', Decimal('41.853732'), Decimal('-87.724311'), 'pink', 1, 'W | E', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (15, 40160, 'LaSalle/Van Buren', datetime.date(2001, 1, 1), 'U', 96, 24, 'winter', Decimal('41.8768'), Decimal('-87.631739'), 'brown', 0, 'E', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000')),
#  (15, 40160, 'LaSalle/Van Buren', datetime.date(2001, 1, 1), 'U', 96, 24, 'winter', Decimal('41.8768'), Decimal('-87.631739'), 'orange', 0, 'W', Decimal('5.3000'), Decimal('1.4870'), Decimal('14.5000'), Decimal('0.0000'), Decimal('17.0000'))]

# %%
# %%sql
#
# REFRESH MATERIALIZED VIEW Rail_Model_Data;
# Out:
#  * postgresql+psycopg2://ctadba:***@10.0.0.220/cta
