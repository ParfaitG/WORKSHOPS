# %% [markdown]
# ## Best Practices in Pandas: Lessons Learned from Answering On
#
# <img style="float: left;" src="IMAGES/StackOverflow.png">

# %% [markdown]
# ### Parfait Gasana
# ChiPy, Data SIG 05/29/2018

# %% [markdown]
# ## What is StackOverflow?
#
# - Programming Q/A site launched September 15, 2008 created by [Jeff Atwood](https://stackoverflow.com/users/1/jeff-atwood) and [Joel Spolsky](https://stackoverflow.com/users/4/joel-spolsky)
# - Built as an *open* alternative to Q/A tech sites such as Experts Exchange
#   - *"Stackoverflow is sort of like the anti-experts-exchange meets Wikipedia meets programming Reddit."*
#
# - Reconceptualized [forum](https://stackoverflow.com/tour) based original post and answering without long scrolling or back and forth threading
# - Uses tags to organize questions in various categories for easy search and filter
#   - Tags usually include languages (C#, Java, Python among most popular) and frameworks and modules (i.e., pandas)
# - Fosters a gaming style with awarded points and badges to various milestones
# - Rigorous, engaged community with moderators voted by users
# - Due to popularity becomes flagship site in StackExchange network: https://stackexchange.com/sites#

# %% [markdown]
# ## Quick Stats
# ** From Query StackOverflow: <br/>
# http://data.stackexchange.com/stackoverflow/query/851060/quick-stats-on-users-questions-answers-comments-count **

# %%
import pandas as pd
import numpy as np

stackoverflow_stats = pd.read_csv('DATA/StackOverflow_QueryResults.csv')

# %%
stackoverflow_stats.apply(lambda col: col.apply(lambda x: "{:,}".format(x)))
# Out:
#    UserCount QuestionsCount CommentsCount AnswersCount AcceptedAnswersCount
# 0  8,852,907     40,530,764    66,127,595   24,578,779            8,454,080

# %% [markdown]
# ## Pandas tag
# - [~70K tagged](https://stackoverflow.com/questions/tagged/pandas) questions
# - Top users: [@jezrael](https://stackoverflow.com/users/2901002/jezrael), [@Andy Hayden](https://stackoverflow.com/users/1240268/andy-hayden), [EdChum](https://stackoverflow.com/users/704848/edchum), [piRSquared](https://stackoverflow.com/users/2336654/pirsquared), [unutbu](https://stackoverflow.com/users/190597/unutbu)
# - [@Parfait](https://stackoverflow.com/users/1422451/parfait): silver badge in python, bronze badge in pandas
#
#   <img style="float: left;" src="IMAGES/StackOverflow_Pandas_TopUsers.png">
#   <img style="float: left; width: 650px" src="IMAGES/StackOverflow_@Parfait.png">
#
# <br/>
#
# ### *"Most questions are more about processing than programming"* -Parfait
#
# ### [How much research effort is expected of Stack Overflow users?](https://meta.stackoverflow.com/a/261593/1422451)

# %% [markdown]
# ***
# ## Best Practices / Guidelines / Use Cases

# %% [markdown]
# ## Set up reproducible examples
# - ** Avoid the [XY Problem](https://meta.stackexchange.com/questions/66377/what-is-the-xy-problem) and "telling" co-workers, teammates, the problem to be troubleshooted. **
# - ** Instead, set up a small randomized example to easily from larger context and "show" error/undesired result. **
#
# ### [How to make good reproducible pandas examples?](https://stackoverflow.com/q/20109391/1422451)
# **([How to make a great R reproducible example?](https://stackoverflow.com/questions/5963269/how-to-make-a-great-r-reproducible-example)**

# %%
# DEMO DATAFRAME OF 50 COLUMNS

np.random.seed(5292018)
demo_df = pd.DataFrame({'date': np.random.choice(pd.date_range('2018-01-01', '2018-05-23', freq='D'), 50),
                        'analysis_tool': np.random.choice(['pandas', 'r', 'julia', 'sas', 'stata', 'spss'],50),              
                        'database': np.random.choice(['postgres', 'mysql', 'sqlite', 'oracle', 'sql server', 'db2'],50), 
                        'os': np.random.choice(['windows 10', 'ubuntu', 'mac os', 'android', 'ios', 'windows 7', 'debian'],50), 
                        'num1': np.random.randn(50)*100,
                        'num2': np.random.uniform(0,1,50),                   
                        'num3': np.random.randint(100, size=50),
                        'bool': np.random.choice([True, False], 50)
                       },
                        columns=['date', 'analysis_tool', 'num1', 'database', 'num2', 'os', 'num3', 'bool']
          )

# %%
demo_df.head(20)
# Out:
#          date analysis_tool        num1    database      num2          os  \
# 0  2018-02-02         julia  -80.809133  sql server  0.802394     android
# 1  2018-05-13         stata -151.799273         db2  0.733028         ios
# 2  2018-05-07         julia -260.442372  sql server  0.624550   windows 7
# 3  2018-01-07          spss  118.412725  sql server  0.108483   windows 7
# 4  2018-03-19          spss   -5.926350       mysql  0.776017      ubuntu
# 5  2018-01-01        pandas -147.378978         db2  0.284513      debian
# 6  2018-03-09        pandas   84.525485  sql server  0.419493   windows 7
# 7  2018-02-09         julia  124.871317  sql server  0.538567         ios
# 8  2018-03-01           sas  149.028167      sqlite  0.030791     android
# 9  2018-01-27          spss   55.330266      sqlite  0.631925     android
# 10 2018-02-08        pandas  220.204327         db2  0.837059         ios
# 11 2018-02-25        pandas -103.699398         db2  0.461672     android
# 12 2018-01-16         julia   13.863508         db2  0.770288      ubuntu
# 13 2018-01-10         julia   14.060413    postgres  0.196518   windows 7
# 14 2018-05-11         stata  -62.120205      sqlite  0.195309  windows 10
# 15 2018-05-21             r  -56.021303      oracle  0.797842  windows 10
# 16 2018-03-02             r  -33.395476      sqlite  0.419473     android
# 17 2018-04-05        pandas  -84.472197  sql server  0.230288      ubuntu
# 18 2018-02-15        pandas  -50.845769       mysql  0.209407      mac os
# 19 2018-03-12           sas   68.422818      sqlite  0.223199      ubuntu
#
#     num3   bool
# 0     65   True
# 1      7  False
# 2     72   True
# 3     13   True
# 4     75  False
# 5     59   True
# 6     51   True
# 7     42  False
# 8     73   True
# 9     60  False
# 10    83   True
# 11    75   True
# 12    18   True
# 13    59   True
# 14    26  False
# 15     8   True
# 16    74  False
# 17    25  False
# 18     2   True
# 19    41   True

# %% [markdown]
# ***
# ## Use containers for similar structures
# - ** Avoid holding many similar structured objects (i.e., dataframes) in separate variables flooding your global environment. **
# - ** Instead, use containers like dicts and lists. **
#
#
# ```
# # LINE BY LINE ASSIGNMENT
# df1 = pd.read_csv('/path/to/data1.csv')
# df2 = pd.read_csv('/path/to/data2.csv')
# df3 = pd.read_csv('/path/to/data3.csv')
#
# # ITERATIVE ASSIGNMENT
# files = ['data1.json','data2.json','data3.json']
#
# for file_name in files:
#     var_name = file_name.split('.')[0][2:]
#     with open(file_name, 'r') as f:
#         data = json.load(f)
#
#     globals()['df_{}'.format(var_name)] = pd.DataFrame(data)
# ```

# %%
# SAVE ITERATIVELY IN CONTAINER
df_dict = {}

for g in demo_df.groupby('analysis_tool'):
    df_dict[g[0]] = g[1].reset_index(drop=True)

# %%
df_dict['pandas'].describe()
# Out:
#              num1       num2       num3
# count   14.000000  14.000000  14.000000
# mean   -26.706063   0.438107  50.642857
# std    111.001591   0.240137  28.532322
# min   -194.989528   0.049702   2.000000
# 25%    -98.892598   0.285937  28.000000
# 50%    -54.453737   0.383158  56.500000
# 75%     45.289531   0.547127  73.250000
# max    220.204327   0.878259  87.000000

# %%
df_dict['r'].head()
# Out:
#         date analysis_tool        num1  database      num2          os  num3  \
# 0 2018-05-21             r  -56.021303    oracle  0.797842  windows 10     8
# 1 2018-03-02             r  -33.395476    sqlite  0.419473     android    74
# 2 2018-04-10             r -104.030615  postgres  0.238031         ios    73
# 3 2018-03-23             r   25.678976       db2  0.592432      debian    99
# 4 2018-01-31             r -164.515717     mysql  0.114143  windows 10    39
#
#     bool
# 0   True
# 1  False
# 2  False
# 3   True
# 4   True

# %%
df_dict['julia'].groupby('database').agg('sum')
# Out:
#                   num1      num2  num3  bool
# database
# db2         -51.683687  1.276695    79   1.0
# mysql       -37.389376  0.277813     3   0.0
# postgres    -15.530212  1.262109   130   3.0
# sql server -318.833453  2.240951   218   2.0

# %% [markdown]
# ***
# ## Do NOT Expand Objects in Loop
# - ** Avoid memory-resources of execessive copying when expanding objects in loops **
# - ** Instead, use containers like dicts and lists and then concatenate or join outside of loop. **
#
# ** https://stackoverflow.com/a/36489724/1422451 -@unutbu **
#
# ```
# # ITERATIVELY BUILD MASTER DATAFRAME
# df = pd.DataFrame()
#
# for i in os.walk('/path/to/data'):
#    df.append(pd.read_csv(os.path.join('/path/to/data', i)))
# ```

# %%
# SAVE ITERATIVELY IN CONTAINER
df_dict = {}

for g in demo_df.groupby('analysis_tool'):
    df_dict[g[0]] = g[1].reset_index(drop=True)
    
# CONCATENTATE WITH CONTAINER OUTSIDE LOOP
final_df = pd.concat(df_dict, ignore_index=True)

final_df.head(20)
# Out:
#          date analysis_tool        num1    database      num2          os  \
# 0  2018-02-02         julia  -80.809133  sql server  0.802394     android
# 1  2018-05-07         julia -260.442372  sql server  0.624550   windows 7
# 2  2018-02-09         julia  124.871317  sql server  0.538567         ios
# 3  2018-01-16         julia   13.863508         db2  0.770288      ubuntu
# 4  2018-01-10         julia   14.060413    postgres  0.196518   windows 7
# 5  2018-04-12         julia  -65.547195         db2  0.506407     android
# 6  2018-03-03         julia -102.453265  sql server  0.275440     android
# 7  2018-01-28         julia  -37.389376       mysql  0.277813     android
# 8  2018-04-30         julia   63.369345    postgres  0.073218     android
# 9  2018-01-12         julia  -92.959970    postgres  0.992373         ios
# 10 2018-01-01        pandas -147.378978         db2  0.284513      debian
# 11 2018-03-09        pandas   84.525485  sql server  0.419493   windows 7
# 12 2018-02-08        pandas  220.204327         db2  0.837059         ios
# 13 2018-02-25        pandas -103.699398         db2  0.461672     android
# 14 2018-04-05        pandas  -84.472197  sql server  0.230288      ubuntu
# 15 2018-02-15        pandas  -50.845769       mysql  0.209407      mac os
# 16 2018-04-24        pandas  -58.061706       mysql  0.049702   windows 7
# 17 2018-05-04        pandas    1.273838      sqlite  0.344150  windows 10
# 18 2018-02-27        pandas   20.013363      sqlite  0.548549     android
# 19 2018-03-05        pandas   79.660529         db2  0.542860   windows 7
#
#     num3   bool
# 0     65   True
# 1     72   True
# 2     42  False
# 3     18   True
# 4     59   True
# 5     61  False
# 6     39  False
# 7      3  False
# 8     37   True
# 9     34   True
# 10    59   True
# 11    51   True
# 12    83   True
# 13    75   True
# 14    25  False
# 15     2   True
# 16    68  False
# 17    54   True
# 18    37   True
# 19    87  False

# %% [markdown]
# ***
# ## Understand import handlers (DataFrame and read_table)
# - ** Avoid added steps of data cleaning after import of data source. **
# - ** Instead, use all available arguments of these methods to handle indexing/dates/types/columns at the source. **

# %%
dict_to_df = pd.DataFrame({'C++': ['computing', 99.6],
                           'C': ['computing', 99.9],
                           'Java': ['application', 100],
                           'C#': ['application', 91.8],
                           'Python': ['application', 95.8],
                           'PHP': ['web', 84.5],
                           'Perl': ['web', 66.9],
                           'R': ['computing', 84.7],
                           'Ruby': ['web', 75.3],
                           'VB.NET': ['application', 63.4],
                           'Javascript': ['web', 83],
                           'Matlab': ['computing', 72.4]
                          })
dict_to_df
# Out:
#            C           C#        C++         Java Javascript     Matlab   PHP  \
# 0  computing  application  computing  application        web  computing   web
# 1       99.9         91.8       99.6          100         83       72.4  84.5
#
#    Perl       Python          R  Ruby       VB.NET
# 0   web  application  computing   web  application
# 1  66.9         95.8       84.7  75.3         63.4

# %%
# TRANSFORMING INTO LONG FORMAT
dict_to_df\
    .T\
    .sort_values(1, ascending=False)\
    .reset_index()\
    .rename(columns={'index':'language', 0:'uses', 1:'ranking'})
# Out:
#       language         uses ranking
# 0         Java  application     100
# 1            C    computing    99.9
# 2          C++    computing    99.6
# 3       Python  application    95.8
# 4           C#  application    91.8
# 5            R    computing    84.7
# 6          PHP          web    84.5
# 7   Javascript          web      83
# 8         Ruby          web    75.3
# 9       Matlab    computing    72.4
# 10        Perl          web    66.9
# 11      VB.NET  application    63.4

# %%
list_to_df = pd.DataFrame([['C++', 'computing', 99.6],
                           ['C', 'computing', 99.9],
                           ['Java', 'application', 100],
                           ['C#', 'application', 91.8],
                           ['Python', 'application', 95.8],
                           ['PHP', 'web', 84.5],
                           ['Perl', 'web', 66.9],
                           ['R', 'computing', 84.7],
                           ['Ruby', 'web', 75.3],
                           ['VB.NET', 'application', 63.4],
                           ['Javascript', 'web', 83],
                           ['Matlab', 'computing', 72.4]])

list_to_df
# Out:
#              0            1      2
# 0          C++    computing   99.6
# 1            C    computing   99.9
# 2         Java  application  100.0
# 3           C#  application   91.8
# 4       Python  application   95.8
# 5          PHP          web   84.5
# 6         Perl          web   66.9
# 7            R    computing   84.7
# 8         Ruby          web   75.3
# 9       VB.NET  application   63.4
# 10  Javascript          web   83.0
# 11      Matlab    computing   72.4

# %%
# RENAMING COLUMNS AND SORTING

(list_to_df.rename(columns={0:'language', 1:'uses', 2:'ranking'})
          .sort_values('ranking', ascending=False)
          .reset_index(drop=True)
)
# Out:
#       language         uses  ranking
# 0         Java  application    100.0
# 1            C    computing     99.9
# 2          C++    computing     99.6
# 3       Python  application     95.8
# 4           C#  application     91.8
# 5            R    computing     84.7
# 6          PHP          web     84.5
# 7   Javascript          web     83.0
# 8         Ruby          web     75.3
# 9       Matlab    computing     72.4
# 10        Perl          web     66.9
# 11      VB.NET  application     63.4

# %%
mat_to_df = pd.DataFrame(np.matrix([['C++', 'computing', '99.6'],
                                    ['C', 'computing', '99.9'],
                                    ['Java', 'application', '100'],
                                    ['C#', 'application', '91.8'],
                                    ['Python', 'application', '95.8'],
                                    ['PHP', 'web', '84.5'],
                                    ['Perl', 'web', '66.9'],
                                    ['R', 'computing', '84.7'],
                                    ['Ruby', 'web', '75.3'],
                                    ['VB.NET', 'application', '63.4'],
                                    ['Javascript', 'web', '83'],
                                    ['Matlab', 'computing', '72.4']], dtype='str'))

mat_to_df
# Out:
#              0            1     2
# 0          C++    computing  99.6
# 1            C    computing  99.9
# 2         Java  application   100
# 3           C#  application  91.8
# 4       Python  application  95.8
# 5          PHP          web  84.5
# 6         Perl          web  66.9
# 7            R    computing  84.7
# 8         Ruby          web  75.3
# 9       VB.NET  application  63.4
# 10  Javascript          web    83
# 11      Matlab    computing  72.4

# %%
# RENAMING COLUMNS, SORTING, AND CONVERTING TYPE

mat_to_df = mat_to_df.rename(columns={0:'language', 1:'uses', 2:'ranking'})
mat_to_df.assign(ranking=mat_to_df['ranking'].astype(float))\
         .sort_values('ranking', ascending=False)\
         .reset_index(drop=True)
# Out:
#       language         uses  ranking
# 0         Java  application    100.0
# 1            C    computing     99.9
# 2          C++    computing     99.6
# 3       Python  application     95.8
# 4           C#  application     91.8
# 5            R    computing     84.7
# 6          PHP          web     84.5
# 7   Javascript          web     83.0
# 8         Ruby          web     75.3
# 9       Matlab    computing     72.4
# 10        Perl          web     66.9
# 11      VB.NET  application     63.4

# %% [markdown]
# ### pandas.read_table arguments:
# (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html)
#
# 1. **IMPORT SPECS**: setting delimiter types, skip rows, use columns, encoding
# 2. **STRUCTURE**: setting headers, assigning index, assigning dtypes
# 3. **DATA MANIPULATION**: parsing dates, float precision, converters
# 4. **PROCESSING**: read in by chunks and buffers
# 5. **CLEANUP**: handling nas, duplicate columns, whitespace, error lines

# %%
from io import StringIO

txt = '''
language 	uses 	ranking
0 	Java 	application 	100.0
1 	C 	computing 	99.9
2 	C++ 	computing 	99.6
3 	Python 	application 	95.8
4 	C# 	application 	91.8
5 	R 	computing 	84.7
6 	PHP 	web 	84.5
7 	Javascript 	web 	83.0
8 	Ruby 	web 	75.3
9 	Matlab 	computing 	72.4
10 	Perl 	web 	66.9
11 	VB.NET 	application 	63.4
'''

pd.read_table(StringIO(txt), sep="\t")
# Out:
#       language          uses   ranking
# 0         Java   application     100.0
# 1            C     computing      99.9
# 2          C++     computing      99.6
# 3       Python   application      95.8
# 4           C#   application      91.8
# 5            R     computing      84.7
# 6          PHP           web      84.5
# 7   Javascript           web      83.0
# 8         Ruby           web      75.3
# 9       Matlab     computing      72.4
# 10        Perl           web      66.9
# 11      VB.NET   application      63.4

# %%
# LONG ROUTE

txt = '''
,,,,,,,
,,,,,,,
,,,,,,,
,,,,,,,
"2018-02-02 00:00:00","julia",-80.80913279329484,"sql server",0.802394455353122,"android",65,True
"2018-05-13 00:00:00","stata",-151.7992726122275,"db2",0.7330284087108757,"ios",7,False
"2018-05-07 00:00:00","julia",-260.4423724467031,"sql server",0.6245499442524706,"windows 7",72,True
"2018-01-07 00:00:00","spss",118.41272509929533,"sql server",0.10848291070194971,"windows 7",13,True
"2018-03-19 00:00:00","spss",-5.926349819586471,"mysql",0.7760168494060156,"ubuntu",75,False
"2018-01-01 00:00:00","pandas",-147.37897756593296,"db2",0.2845131673369167,"debian",59,True
"2018-03-09 00:00:00","pandas",84.52548456619385,"sql server",0.4194926483292597,"windows 7",51,True
"2018-02-09 00:00:00","julia",124.87131746250854,"sql server",0.5385665717612856,"ios",42,False
"2018-03-01 00:00:00","sas",149.02816690535462,"sqlite",0.030791059245802943,"android",73,True
"2018-01-27 00:00:00","spss",55.3302663331162,"sqlite",0.631924826527541,"android",60,False
'''

csv_df = pd.read_csv(StringIO(txt), header=None)

csv_df = csv_df[4:].reset_index(drop=True)
csv_df.columns = ['date', 'analysis_tool', 'num1', 'database', 'num2', 'os', 'num3', 'bool']
csv_df['date'] = pd.to_datetime(csv_df['date'])
csv_df['num3'] = csv_df['num3'].astype(int)
csv_df['bool'] = csv_df['bool'].astype(bool)

csv_df
# Out:
#         date analysis_tool        num1    database      num2         os  num3  \
# 0 2018-02-02         julia  -80.809133  sql server  0.802394    android    65
# 1 2018-05-13         stata -151.799273         db2  0.733028        ios     7
# 2 2018-05-07         julia -260.442372  sql server  0.624550  windows 7    72
# 3 2018-01-07          spss  118.412725  sql server  0.108483  windows 7    13
# 4 2018-03-19          spss   -5.926350       mysql  0.776017     ubuntu    75
# 5 2018-01-01        pandas -147.378978         db2  0.284513     debian    59
# 6 2018-03-09        pandas   84.525485  sql server  0.419493  windows 7    51
# 7 2018-02-09         julia  124.871317  sql server  0.538567        ios    42
# 8 2018-03-01           sas  149.028167      sqlite  0.030791    android    73
# 9 2018-01-27          spss   55.330266      sqlite  0.631925    android    60
#
#     bool
# 0   True
# 1  False
# 2   True
# 3   True
# 4  False
# 5   True
# 6   True
# 7  False
# 8   True
# 9  False

# %%
# SHORT ROUTE

txt = '''
,,,,,,,
,,,,,,,
,,,,,,,
,,,,,,,
"2018-02-02 00:00:00","julia",-80.80913279329484,"sql server",0.802394455353122,"android",65,True
"2018-05-13 00:00:00","stata",-151.7992726122275,"db2",0.7330284087108757,"ios",7,False
"2018-05-07 00:00:00","julia",-260.4423724467031,"sql server",0.6245499442524706,"windows 7",72,True
"2018-01-07 00:00:00","spss",118.41272509929533,"sql server",0.10848291070194971,"windows 7",13,True
"2018-03-19 00:00:00","spss",-5.926349819586471,"mysql",0.7760168494060156,"ubuntu",75,False
"2018-01-01 00:00:00","pandas",-147.37897756593296,"db2",0.2845131673369167,"debian",59,True
"2018-03-09 00:00:00","pandas",84.52548456619385,"sql server",0.4194926483292597,"windows 7",51,True
"2018-02-09 00:00:00","julia",124.87131746250854,"sql server",0.5385665717612856,"ios",42,False
"2018-03-01 00:00:00","sas",149.02816690535462,"sqlite",0.030791059245802943,"android",73,True
"2018-01-27 00:00:00","spss",55.3302663331162,"sqlite",0.631924826527541,"android",60,False
'''

funcs = {'num3': lambda x: np.nan if x == '' else int(x),
         'bool': lambda x: np.nan if x == '' else bool(x)}

csv_df = pd.read_csv(StringIO(txt), header=None, skiprows=5, parse_dates=[0],
                     names=['date', 'analysis_tool', 'num1', 'database', 'num2', 'os', 'num3', 'bool'],
                     converters = funcs)

csv_df
# Out:
#         date analysis_tool        num1    database      num2         os  num3  \
# 0 2018-02-02         julia  -80.809133  sql server  0.802394    android    65
# 1 2018-05-13         stata -151.799273         db2  0.733028        ios     7
# 2 2018-05-07         julia -260.442372  sql server  0.624550  windows 7    72
# 3 2018-01-07          spss  118.412725  sql server  0.108483  windows 7    13
# 4 2018-03-19          spss   -5.926350       mysql  0.776017     ubuntu    75
# 5 2018-01-01        pandas -147.378978         db2  0.284513     debian    59
# 6 2018-03-09        pandas   84.525485  sql server  0.419493  windows 7    51
# 7 2018-02-09         julia  124.871317  sql server  0.538567        ios    42
# 8 2018-03-01           sas  149.028167      sqlite  0.030791    android    73
# 9 2018-01-27          spss   55.330266      sqlite  0.631925    android    60
#
#    bool
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True
# 5  True
# 6  True
# 7  True
# 8  True
# 9  True

# %%
csv_df = pd.read_csv(StringIO("\n".join(txt.split('\n')[5:])), header=None, parse_dates=[0],
                     names=['date', 'analysis_tool', 'num1', 'database', 'num2', 'os', 'num3', 'bool'],
                     dtype={'num3': int, 'bool':bool})

csv_df
# Out:
#         date analysis_tool        num1    database      num2         os  num3  \
# 0 2018-02-02         julia  -80.809133  sql server  0.802394    android    65
# 1 2018-05-13         stata -151.799273         db2  0.733028        ios     7
# 2 2018-05-07         julia -260.442372  sql server  0.624550  windows 7    72
# 3 2018-01-07          spss  118.412725  sql server  0.108483  windows 7    13
# 4 2018-03-19          spss   -5.926350       mysql  0.776017     ubuntu    75
# 5 2018-01-01        pandas -147.378978         db2  0.284513     debian    59
# 6 2018-03-09        pandas   84.525485  sql server  0.419493  windows 7    51
# 7 2018-02-09         julia  124.871317  sql server  0.538567        ios    42
# 8 2018-03-01           sas  149.028167      sqlite  0.030791    android    73
# 9 2018-01-27          spss   55.330266      sqlite  0.631925    android    60
#
#     bool
# 0   True
# 1  False
# 2   True
# 3   True
# 4  False
# 5   True
# 6   True
# 7  False
# 8   True
# 9  False

# %% [markdown]
# ***
# ## Appreciate and recognize the index property
# - ** Avoid seeing index as a convenient row number. **
# - ** Instead, use its properties and operations to interact with your data. **

# %%
demo_df.head(10)
# Out:
#         date analysis_tool        num1    database      num2         os  num3  \
# 0 2018-02-02         julia  -80.809133  sql server  0.802394    android    65
# 1 2018-05-13         stata -151.799273         db2  0.733028        ios     7
# 2 2018-05-07         julia -260.442372  sql server  0.624550  windows 7    72
# 3 2018-01-07          spss  118.412725  sql server  0.108483  windows 7    13
# 4 2018-03-19          spss   -5.926350       mysql  0.776017     ubuntu    75
# 5 2018-01-01        pandas -147.378978         db2  0.284513     debian    59
# 6 2018-03-09        pandas   84.525485  sql server  0.419493  windows 7    51
# 7 2018-02-09         julia  124.871317  sql server  0.538567        ios    42
# 8 2018-03-01           sas  149.028167      sqlite  0.030791    android    73
# 9 2018-01-27          spss   55.330266      sqlite  0.631925    android    60
#
#     bool
# 0   True
# 1  False
# 2   True
# 3   True
# 4  False
# 5   True
# 6   True
# 7  False
# 8   True
# 9  False

# %%
demo_df.loc[2:3]
# Out:
#         date analysis_tool        num1    database      num2         os  num3  \
# 2 2018-05-07         julia -260.442372  sql server  0.624550  windows 7    72
# 3 2018-01-07          spss  118.412725  sql server  0.108483  windows 7    13
#
#    bool
# 2  True
# 3  True

# %%
demo_df.loc[2:3, ["analysis_tool", "os"]]
# Out:
#   analysis_tool         os
# 2         julia  windows 7
# 3          spss  windows 7

# %%
demo_idx_df = demo_df.sort_values(['analysis_tool', 'database'])\
                     .set_index(['analysis_tool', 'database'])
demo_idx_df
# Out:
#                                date        num1      num2          os  num3  \
# analysis_tool database
# julia         db2        2018-01-16   13.863508  0.770288      ubuntu    18
#               db2        2018-04-12  -65.547195  0.506407     android    61
#               mysql      2018-01-28  -37.389376  0.277813     android     3
#               postgres   2018-01-10   14.060413  0.196518   windows 7    59
#               postgres   2018-04-30   63.369345  0.073218     android    37
#               postgres   2018-01-12  -92.959970  0.992373         ios    34
#               sql server 2018-02-02  -80.809133  0.802394     android    65
#               sql server 2018-05-07 -260.442372  0.624550   windows 7    72
#               sql server 2018-02-09  124.871317  0.538567         ios    42
#               sql server 2018-03-03 -102.453265  0.275440     android    39
# pandas        db2        2018-01-01 -147.378978  0.284513      debian    59
#               db2        2018-02-08  220.204327  0.837059         ios    83
#               db2        2018-02-25 -103.699398  0.461672     android    75
#               db2        2018-03-05   79.660529  0.542860   windows 7    87
#               mysql      2018-02-15  -50.845769  0.209407      mac os     2
#               mysql      2018-04-24  -58.061706  0.049702   windows 7    68
#               mysql      2018-03-21 -194.989528  0.878259      ubuntu    13
#               mysql      2018-01-02 -132.431026  0.346823      mac os    80
#               mysql      2018-05-17   53.714920  0.690518         ios    11
#               oracle     2018-02-22  -61.398740  0.290208      mac os    64
#               sql server 2018-03-09   84.525485  0.419493   windows 7    51
#               sql server 2018-04-05  -84.472197  0.230288      ubuntu    25
#               sqlite     2018-05-04    1.273838  0.344150  windows 10    54
#               sqlite     2018-02-27   20.013363  0.548549     android    37
# r             db2        2018-03-23   25.678976  0.592432      debian    99
#               mysql      2018-01-31 -164.515717  0.114143  windows 10    39
#               oracle     2018-05-21  -56.021303  0.797842  windows 10     8
#               postgres   2018-04-10 -104.030615  0.238031         ios    73
#               sqlite     2018-03-02  -33.395476  0.419473     android    74
# sas           mysql      2018-02-22  102.520173  0.613246  windows 10     5
#               postgres   2018-03-15   19.871705  0.208399      mac os    40
#               postgres   2018-04-15   66.723778  0.556798  windows 10    62
#               sql server 2018-03-17  -72.907403  0.282253   windows 7    66
#               sql server 2018-03-02    2.573104  0.428336  windows 10    29
#               sqlite     2018-03-01  149.028167  0.030791     android    73
#               sqlite     2018-03-12   68.422818  0.223199      ubuntu    41
# spss          mysql      2018-03-19   -5.926350  0.776017      ubuntu    75
#               mysql      2018-03-17   37.701401  0.431457     android    14
#               postgres   2018-02-23   93.774420  0.687521      ubuntu    28
#               sql server 2018-01-07  118.412725  0.108483   windows 7    13
#               sqlite     2018-01-27   55.330266  0.631925     android    60
#               sqlite     2018-01-02  -62.283072  0.854173      mac os    74
#               sqlite     2018-02-05 -124.423422  0.160935      debian    57
# stata         db2        2018-05-13 -151.799273  0.733028         ios     7
#               oracle     2018-03-18  -37.368677  0.961842      mac os    64
#               postgres   2018-04-19  -59.431810  0.860143         ios    31
#               postgres   2018-01-06   44.591954  0.445536      mac os    77
#               sqlite     2018-05-11  -62.120205  0.195309  windows 10    26
#               sqlite     2018-04-14    0.965033  0.164291     android     4
#               sqlite     2018-03-12   12.338333  0.316733      debian    44
#
#                            bool
# analysis_tool database
# julia         db2          True
#               db2         False
#               mysql       False
#               postgres     True
#               postgres     True
#               postgres     True
#               sql server   True
#               sql server   True
#               sql server  False
#               sql server  False
# pandas        db2          True
#               db2          True
#               db2          True
#               db2         False
#               mysql        True
#               mysql       False
#               mysql        True
#               mysql        True
#               mysql        True
#               oracle       True
#               sql server   True
#               sql server  False
#               sqlite       True
#               sqlite       True
# r             db2          True
#               mysql        True
#               oracle       True
#               postgres    False
#               sqlite      False
# sas           mysql       False
#               postgres    False
#               postgres     True
#               sql server  False
#               sql server  False
#               sqlite       True
#               sqlite       True
# spss          mysql       False
#               mysql       False
#               postgres    False
#               sql server   True
#               sqlite      False
#               sqlite       True
#               sqlite      False
# stata         db2         False
#               oracle       True
#               postgres     True
#               postgres     True
#               sqlite      False
#               sqlite       True
#               sqlite       True

# %%
demo_idx_df.loc['pandas']
# Out:
#                  date        num1      num2          os  num3   bool
# database
# db2        2018-01-01 -147.378978  0.284513      debian    59   True
# db2        2018-02-08  220.204327  0.837059         ios    83   True
# db2        2018-02-25 -103.699398  0.461672     android    75   True
# db2        2018-03-05   79.660529  0.542860   windows 7    87  False
# mysql      2018-02-15  -50.845769  0.209407      mac os     2   True
# mysql      2018-04-24  -58.061706  0.049702   windows 7    68  False
# mysql      2018-03-21 -194.989528  0.878259      ubuntu    13   True
# mysql      2018-01-02 -132.431026  0.346823      mac os    80   True
# mysql      2018-05-17   53.714920  0.690518         ios    11   True
# oracle     2018-02-22  -61.398740  0.290208      mac os    64   True
# sql server 2018-03-09   84.525485  0.419493   windows 7    51   True
# sql server 2018-04-05  -84.472197  0.230288      ubuntu    25  False
# sqlite     2018-05-04    1.273838  0.344150  windows 10    54   True
# sqlite     2018-02-27   20.013363  0.548549     android    37   True

# %%
demo_idx_df.loc[['pandas','r']]
# Out:
#                                date        num1      num2          os  num3  \
# analysis_tool database
# pandas        db2        2018-01-01 -147.378978  0.284513      debian    59
#               db2        2018-02-08  220.204327  0.837059         ios    83
#               db2        2018-02-25 -103.699398  0.461672     android    75
#               db2        2018-03-05   79.660529  0.542860   windows 7    87
#               mysql      2018-02-15  -50.845769  0.209407      mac os     2
#               mysql      2018-04-24  -58.061706  0.049702   windows 7    68
#               mysql      2018-03-21 -194.989528  0.878259      ubuntu    13
#               mysql      2018-01-02 -132.431026  0.346823      mac os    80
#               mysql      2018-05-17   53.714920  0.690518         ios    11
#               oracle     2018-02-22  -61.398740  0.290208      mac os    64
#               sql server 2018-03-09   84.525485  0.419493   windows 7    51
#               sql server 2018-04-05  -84.472197  0.230288      ubuntu    25
#               sqlite     2018-05-04    1.273838  0.344150  windows 10    54
#               sqlite     2018-02-27   20.013363  0.548549     android    37
# r             db2        2018-03-23   25.678976  0.592432      debian    99
#               mysql      2018-01-31 -164.515717  0.114143  windows 10    39
#               oracle     2018-05-21  -56.021303  0.797842  windows 10     8
#               postgres   2018-04-10 -104.030615  0.238031         ios    73
#               sqlite     2018-03-02  -33.395476  0.419473     android    74
#
#                            bool
# analysis_tool database
# pandas        db2          True
#               db2          True
#               db2          True
#               db2         False
#               mysql        True
#               mysql       False
#               mysql        True
#               mysql        True
#               mysql        True
#               oracle       True
#               sql server   True
#               sql server  False
#               sqlite       True
#               sqlite       True
# r             db2          True
#               mysql        True
#               oracle       True
#               postgres    False
#               sqlite      False

# %%
demo_idx_df.loc['pandas','mysql']
# Out:
#                              date        num1      num2         os  num3  \
# analysis_tool database
# pandas        mysql    2018-02-15  -50.845769  0.209407     mac os     2
#               mysql    2018-04-24  -58.061706  0.049702  windows 7    68
#               mysql    2018-03-21 -194.989528  0.878259     ubuntu    13
#               mysql    2018-01-02 -132.431026  0.346823     mac os    80
#               mysql    2018-05-17   53.714920  0.690518        ios    11
#
#                          bool
# analysis_tool database
# pandas        mysql      True
#               mysql     False
#               mysql      True
#               mysql      True
#               mysql      True

# %%
import matplotlib.pyplot as plt

# CREATE DATE INDEX

# GROUPBY + PIVOT
pvt_df = demo_df[['date', 'analysis_tool', 'num2']]\
             .groupby(['date', 'analysis_tool'], as_index=False)['num2'].sum()\
             .pivot(index='date', columns='analysis_tool', values='num2')

# PIVOT_TABLE
pvt_df = demo_df[['date', 'analysis_tool', 'num2']]\
             .pivot_table(index='date', columns='analysis_tool', values='num2', aggfunc='sum')
        
pvt_df = pvt_df.resample("D").ffill().fillna(0)

pvt_df.head(15)
# Out:
# analysis_tool     julia    pandas    r  sas      spss     stata
# date
# 2018-01-01     0.000000  0.284513  0.0  0.0  0.000000  0.000000
# 2018-01-02     0.000000  0.346823  0.0  0.0  0.854173  0.000000
# 2018-01-03     0.000000  0.346823  0.0  0.0  0.854173  0.000000
# 2018-01-04     0.000000  0.346823  0.0  0.0  0.854173  0.000000
# 2018-01-05     0.000000  0.346823  0.0  0.0  0.854173  0.000000
# 2018-01-06     0.000000  0.000000  0.0  0.0  0.000000  0.445536
# 2018-01-07     0.000000  0.000000  0.0  0.0  0.108483  0.000000
# 2018-01-08     0.000000  0.000000  0.0  0.0  0.108483  0.000000
# 2018-01-09     0.000000  0.000000  0.0  0.0  0.108483  0.000000
# 2018-01-10     0.196518  0.000000  0.0  0.0  0.000000  0.000000
# 2018-01-11     0.196518  0.000000  0.0  0.0  0.000000  0.000000
# 2018-01-12     0.992373  0.000000  0.0  0.0  0.000000  0.000000
# 2018-01-13     0.992373  0.000000  0.0  0.0  0.000000  0.000000
# 2018-01-14     0.992373  0.000000  0.0  0.0  0.000000  0.000000
# 2018-01-15     0.992373  0.000000  0.0  0.0  0.000000  0.000000

# %%
pvt_df.plot(kind='line', figsize=(15,6)).legend(bbox_to_anchor=(1.0, 1.0))

plt.show()

plt.clf()
plt.close()

# %%
import matplotlib
matplotlib.style.use('ggplot')

pvt_df = pvt_df.resample("M").mean()

pvt_df.plot(kind='bar', figsize=(15,6), rot=0)

plt.show()

plt.clf()
plt.close()

# %% [markdown]
# ***
# ## Recognize the Relationship of Series and DataFrame objects
# - ** Avoid inefficient wrangling and munging processes due to misunderstanding of objects. **
# - ** Instead, appreciating the nature and properties of core objects. **

# %%
# PANDAS DATAFRAME = CONTAINER FOR EQUAL LENGTH PANDAS SERIES

#demo_df.apply(lambda col: type(col)).rename('column_type').to_frame()

# %% [markdown]
# ## Vectorize processes over loop/apply
# - ** Avoid iterating across rows and columns for computation needs. **
# - ** Instead, run blockwise operations across whole series and dataframe objects. **

# %%
date_df = pd.DataFrame()

# FILTER FOR MAY DATES
for dt in pd.date_range('2018-05-01', '2018-05-31', freq='D'):
    tmp = demo_df[demo_df['date']==dt] 
    date_df = date_df.append(tmp, ignore_index=True)

date_df
# Out:
#         date analysis_tool        num1    database      num2          os  \
# 0 2018-05-04        pandas    1.273838      sqlite  0.344150  windows 10
# 1 2018-05-07         julia -260.442372  sql server  0.624550   windows 7
# 2 2018-05-11         stata  -62.120205      sqlite  0.195309  windows 10
# 3 2018-05-13         stata -151.799273         db2  0.733028         ios
# 4 2018-05-17        pandas   53.714920       mysql  0.690518         ios
# 5 2018-05-21             r  -56.021303      oracle  0.797842  windows 10
#
#    num3   bool
# 0    54   True
# 1    72   True
# 2    26  False
# 3     7  False
# 4    11   True
# 5     8   True

# %%
date_df = demo_df[demo_df['date'].between('2018-05-01', '2018-05-31')].reset_index(drop=True)

date_df
# Out:
#         date analysis_tool        num1    database      num2          os  \
# 0 2018-05-13         stata -151.799273         db2  0.733028         ios
# 1 2018-05-07         julia -260.442372  sql server  0.624550   windows 7
# 2 2018-05-11         stata  -62.120205      sqlite  0.195309  windows 10
# 3 2018-05-21             r  -56.021303      oracle  0.797842  windows 10
# 4 2018-05-04        pandas    1.273838      sqlite  0.344150  windows 10
# 5 2018-05-17        pandas   53.714920       mysql  0.690518         ios
#
#    num3   bool
# 0     7  False
# 1    72   True
# 2    26  False
# 3     8   True
# 4    54   True
# 5    11   True

# %% [markdown]
# ***
# ## Keep Data in Long format not Wide
# - ** Avoid inefficient wrangling and munging processes due to shape of data. ***
# - ** Instead, "think like a DBA" (long/many rows, indexing, indicators adjacent to values). **

# %%
census_df = pd.read_csv('DATA/CHI_CommAreas_Census2010.csv', skiprows=1)

census_df.head(10)
# Out:
#               Geog  GeogKey  Total Population  \
# 0      Rogers Park        1             54991
# 1       West Ridge        2             71942
# 2           Uptown        3             56362
# 3   Lincoln Square        4             39493
# 4     North Center        5             31867
# 5        Lake View        6             94368
# 6     Lincoln Park        7             64116
# 7  Near North Side        8             80484
# 8      Edison Park        9             11187
# 9     Norwood Park       10             37023
#
#    Not Hispanic or Latino, White alone  \
# 0                                21618
# 1                                30706
# 2                                29098
# 3                                24916
# 4                                24634
# 5                                75845
# 6                                53138
# 7                                58033
# 8                                 9885
# 9                                30157
#
#    Not Hispanic or Latino, Black or African American alone  \
# 0                                              14461
# 1                                               8015
# 2                                              11275
# 3                                               1488
# 4                                                738
# 5                                               3651
# 6                                               2753
# 7                                               8732
# 8                                                 29
# 9                                                164
#
#    Not Hispanic or Latino, American Indian and Alaska Native alone  \
# 0                                                142
# 1                                                189
# 2                                                191
# 3                                                 72
# 4                                                 55
# 5                                                110
# 6                                                 54
# 7                                                 79
# 8                                                  3
# 9                                                 54
#
#    Not Hispanic or Latino, Asian alone  \
# 0                                 3523
# 1                                16184
# 2                                 6414
# 3                                 4399
# 4                                 1449
# 5                                 5653
# 6                                 3296
# 7                                 8140
# 8                                  269
# 9                                 1696
#
#    Not Hispanic or Latino, Native Hawaiian and Other Pacific Islander alone  \
# 0                                                 39
# 1                                                  3
# 2                                                 10
# 3                                                 11
# 4                                                 16
# 5                                                 44
# 6                                                 17
# 7                                                 25
# 8                                                  1
# 9                                                  1
#
#    Not Hispanic or Latino, Some Other Race alone  \
# 0                                            202
# 1                                            225
# 2                                            130
# 3                                            128
# 4                                             51
# 5                                            140
# 6                                            116
# 7                                            163
# 8                                              8
# 9                                             38
#
#    Not Hispanic or Latino, Two or More Races       ...         Median Age  \
# 0                                       1573       ...               32.4
# 1                                       1919       ...               35.1
# 2                                       1235       ...               35.5
# 3                                        917       ...               33.5
# 4                                        594       ...               32.5
# 5                                       1727       ...               30.4
# 6                                       1171       ...               28.9
# 7                                       1338       ...               35.2
# 8                                        120       ...               41.4
# 9                                        471       ...               43.0
#
#    Total Households  Average Household Size  Total Housing Units  \
# 0             24292                    2.13                27564
# 1             24755                    2.85                27466
# 2             29719                    1.79                32541
# 3             18194                    2.14                19906
# 4             14561                    2.18                16197
# 5             54425                    1.72                59529
# 6             33536                    1.80                36864
# 7             51714                    1.52                62364
# 8              4726                    2.37                 4964
# 9             14937                    2.44                15848
#
#    Occupied Housing Units  Vacant Housing Units  Occupied Housing Units.1  \
# 0                   24292                  3272                     24292
# 1                   24755                  2711                     24755
# 2                   29719                  2822                     29719
# 3                   18194                  1712                     18194
# 4                   14561                  1636                     14561
# 5                   54425                  5104                     54425
# 6                   33536                  3328                     33536
# 7                   51714                 10650                     51714
# 8                    4726                   238                      4726
# 9                   14937                   911                     14937
#
#    Owned with a mortgage or a loan  Owned free and clear  Renter occupied
# 0                             6128                  1009            17155
# 1                             8829                  3367            12559
# 2                             8298                  1230            20191
# 3                             5482                  1406            11306
# 4                             5805                  1147             7609
# 5                            16640                  3488            34297
# 6                            11409                  2963            19164
# 7                            17237                  5991            28486
# 8                             2478                  1186             1062
# 9                             7758                  4009             3170
#
# [10 rows x 67 columns]

# %%
census_df.shape
# Out:
# (77, 67)

# %%
gender_df = census_df.filter(regex='Geog|Total|Male|Female', axis=1)
gender_df
# Out:
#                       Geog  GeogKey  Total Population  \
# 0              Rogers Park        1             54991
# 1               West Ridge        2             71942
# 2                   Uptown        3             56362
# 3           Lincoln Square        4             39493
# 4             North Center        5             31867
# 5                Lake View        6             94368
# 6             Lincoln Park        7             64116
# 7          Near North Side        8             80484
# 8              Edison Park        9             11187
# 9             Norwood Park       10             37023
# 10          Jefferson Park       11             25448
# 11             Forest Glen       12             18508
# 12              North Park       13             17931
# 13             Albany Park       14             51542
# 14            Portage Park       15             64124
# 15             Irving Park       16             53359
# 16                 Dunning       17             41932
# 17               Montclare       18             13426
# 18          Belmont Cragin       19             78743
# 19                 Hermosa       20             25010
# 20                Avondale       21             39262
# 21            Logan Square       22             72791
# 22           Humboldt Park       23             56323
# 23               West Town       24             82236
# 24                  Austin       25             98514
# 25      West Garfield Park       26             18001
# 26      East Garfield Park       27             20567
# 27          Near West Side       28             54881
# 28          North Lawndale       29             35912
# 29          South Lawndale       30             79288
# ..                     ...      ...               ...
# 47         Calumet Heights       48             13812
# 48                Roseland       49             44619
# 49                 Pullman       50              7325
# 50           South Deering       51             15109
# 51               East Side       52             23042
# 52            West Pullman       53             29651
# 53               Riverdale       54              6482
# 54               Hegewisch       55              9426
# 55          Garfield Ridge       56             34513
# 56          Archer Heights       57             13393
# 57           Brighton Park       58             45368
# 58           McKinley Park       59             15612
# 59              Bridgeport       60             31977
# 60                New City       61             44377
# 61             West Elsdon       62             18109
# 62               Gage Park       63             39894
# 63                Clearing       64             23139
# 64               West Lawn       65             33355
# 65            Chicago Lawn       66             55628
# 66          West Englewood       67             35505
# 67               Englewood       68             30654
# 68  Greater Grand Crossing       69             32602
# 69                 Ashburn       70             41081
# 70          Auburn Gresham       71             48743
# 71                 Beverly       72             20034
# 72      Washington Heights       73             26493
# 73         Mount Greenwood       74             19093
# 74             Morgan Park       75             22544
# 75                  O'Hare       76             12756
# 76               Edgewater       77             56521
#
#     Male: Under 5 years old  Male: 5 to 9 years  Male: 10 to 14 years  \
# 0                      1892                1426                  1186
# 1                      2940                2611                  2296
# 2                      1453                 954                   843
# 3                      1313                 883                   718
# 4                      1453                 885                   486
# 5                      2228                1121                   682
# 6                      1600                1032                   765
# 7                      1339                 692                   572
# 8                       311                 391                   342
# 9                      1032                1115                  1079
# 10                      756                 721                   690
# 11                      582                 720                   665
# 12                      537                 533                   558
# 13                     2126                1899                  1624
# 14                     2183                1993                  1956
# 15                     2016                1598                  1605
# 16                     1231                1207                  1129
# 17                      510                 473                   478
# 18                     3549                3151                  3207
# 19                     1103                1083                   985
# 20                     1621                1306                  1243
# 21                     2676                2088                  1888
# 22                     2500                2336                  2381
# 23                     2717                1542                  1395
# 24                     3684                3503                  3845
# 25                      717                 670                   785
# 26                      776                 770                   897
# 27                     1558                 868                   855
# 28                     1603                1563                  1659
# 29                     3710                3356                  3062
# ..                      ...                 ...                   ...
# 47                      324                 326                   452
# 48                     1382                1436                  1640
# 49                      241                 257                   273
# 50                      545                 573                   650
# 51                      953                 947                  1035
# 52                     1030                1073                  1199
# 53                      322                 335                   455
# 54                      329                 352                   358
# 55                     1125                1118                  1132
# 56                      597                 574                   559
# 57                     2309                2239                  2109
# 58                      592                 609                   614
# 59                      987                 911                   952
# 60                     2223                2138                  2183
# 61                      767                 837                   768
# 62                     2037                2071                  1978
# 63                      797                 819                   830
# 64                     1487                1494                  1481
# 65                     2447                2498                  2494
# 66                     1381                1336                  1563
# 67                     1223                1225                  1330
# 68                     1230                1182                  1277
# 69                     1409                1644                  1779
# 70                     1581                1584                  1837
# 71                      597                 737                   776
# 72                      716                 747                   976
# 73                      630                 651                   646
# 74                      610                 694                   807
# 75                      473                 307                   205
# 76                     1297                 939                   768
#
#     Male: 15 to 17 years  Male: 18 and 19 years  Male: 20 years  \
# 0                    816                    802             522
# 1                   1436                    856             422
# 2                    547                    358             228
# 3                    465                    286             151
# 4                    218                    137              95
# 5                    338                    316             450
# 6                    400                   1015             625
# 7                    373                    367             306
# 8                    179                     77              40
# 9                    613                    335             163
# 10                   455                    272             115
# 11                   339                    173              73
# 12                   399                    298             128
# 13                   988                    820             496
# 14                  1282                    833             450
# 15                   938                    614             315
# 16                   725                    548             260
# 17                   281                    162              80
# 18                  1977                   1330             675
# 19                   655                    425             212
# 20                   752                    518             276
# 21                  1094                    726             489
# 22                  1530                   1000             480
# 23                   830                    549             391
# 24                  2613                   1591             753
# 25                   620                    367             142
# 26                   646                    369             176
# 27                   739                    933             589
# 28                  1157                    645             328
# 29                  2023                   1903            1041
# ..                   ...                    ...             ...
# 47                   300                    170              64
# 48                  1178                    725             342
# 49                   186                    106              56
# 50                   406                    236             101
# 51                   611                    387             171
# 52                   892                    525             214
# 53                   283                    111              46
# 54                   221                    128              65
# 55                   704                    429             225
# 56                   347                    203             109
# 57                  1289                    747             386
# 58                   351                    229              98
# 59                   610                    378             246
# 60                  1346                    771             385
# 61                   426                    316             137
# 62                  1126                    724             401
# 63                   471                    270             126
# 64                   829                    547             263
# 65                  1566                    949             475
# 66                  1109                    701             355
# 67                   937                    557             250
# 68                   884                    469             216
# 69                  1068                    638             306
# 70                  1268                    738             390
# 71                   522                    224              88
# 72                   688                    393             180
# 73                   372                    343             156
# 74                   606                    328             145
# 75                   130                     86              33
# 76                   483                    827             496
#
#     Male: 21 years         ...           Female: 60 and 61 years  \
# 0              554         ...                               486
# 1              442         ...                               794
# 2              303         ...                               561
# 3              198         ...                               322
# 4               95         ...                               261
# 5              533         ...                               652
# 6              604         ...                               543
# 7              400         ...                              1101
# 8               48         ...                               141
# 9              171         ...                               454
# 10             113         ...                               351
# 11              76         ...                               251
# 12             126         ...                               214
# 13             492         ...                               413
# 14             437         ...                               764
# 15             328         ...                               481
# 16             244         ...                               544
# 17              97         ...                               170
# 18             644         ...                               656
# 19             206         ...                               204
# 20             310         ...                               374
# 21             495         ...                               508
# 22             465         ...                               521
# 23             437         ...                               480
# 24             689         ...                              1306
# 25             169         ...                               177
# 26             138         ...                               209
# 27             589         ...                               382
# 28             309         ...                               332
# 29            1052         ...                               451
# ..             ...         ...                               ...
# 47              64         ...                               225
# 48             305         ...                               624
# 49              42         ...                               109
# 50             103         ...                               180
# 51             191         ...                               226
# 52             215         ...                               420
# 53              35         ...                                52
# 54              57         ...                               103
# 55             206         ...                               370
# 56             111         ...                               111
# 57             380         ...                               309
# 58             126         ...                               156
# 59             272         ...                               376
# 60             372         ...                               316
# 61             124         ...                               139
# 62             337         ...                               228
# 63             130         ...                               241
# 64             238         ...                               253
# 65             442         ...                               486
# 66             285         ...                               402
# 67             250         ...                               323
# 68             188         ...                               412
# 69             315         ...                               440
# 70             315         ...                               688
# 71              83         ...                               359
# 72             175         ...                               377
# 73             151         ...                               170
# 74             130         ...                               313
# 75              56         ...                               171
# 76             382         ...                               601
#
#     Female: 62 to 64 years  Female: 65 and 66 years  Female: 67 to 69 years  \
# 0                      661                      308                     383
# 1                     1026                      561                     718
# 2                      679                      360                     475
# 3                      493                      256                     323
# 4                      314                      159                     218
# 5                      962                      532                     657
# 6                      770                      431                     532
# 7                     1659                      897                    1166
# 8                      164                       95                     147
# 9                      641                      363                     495
# 10                     450                      226                     338
# 11                     356                      187                     295
# 12                     311                      218                     256
# 13                     503                      281                     396
# 14                    1029                      475                     650
# 15                     744                      363                     463
# 16                     759                      419                     511
# 17                     213                      112                     167
# 18                     811                      546                     587
# 19                     247                      143                     166
# 20                     438                      248                     344
# 21                     655                      337                     463
# 22                     619                      351                     476
# 23                     639                      347                     470
# 24                    1626                      887                    1200
# 25                     207                      116                     183
# 26                     254                      133                     158
# 27                     526                      295                     356
# 28                     384                      245                     306
# 29                     589                      315                     379
# ..                     ...                      ...                     ...
# 47                     338                      236                     378
# 48                     811                      502                     848
# 49                     154                       72                     116
# 50                     265                      181                     245
# 51                     254                      123                     174
# 52                     563                      362                     525
# 53                      69                       29                      51
# 54                     156                       74                     131
# 55                     522                      290                     433
# 56                     146                       69                     100
# 57                     349                      184                     238
# 58                     175                       83                     121
# 59                     430                      208                     324
# 60                     371                      195                     305
# 61                     200                      113                     124
# 62                     344                      147                     192
# 63                     334                      172                     242
# 64                     329                      181                     235
# 65                     586                      326                     416
# 66                     576                      311                     493
# 67                     365                      221                     324
# 68                     476                      282                     343
# 69                     513                      278                     360
# 70                     973                      547                     819
# 71                     406                      223                     204
# 72                     522                      310                     535
# 73                     233                      121                     197
# 74                     371                      218                     353
# 75                     180                       94                     178
# 76                     841                      454                     683
#
#     Female: 70 to 74 years  Female: 75 to 79 years  Female: 80 to 84 years  \
# 0                      534                     392                     312
# 1                     1056                     799                     713
# 2                      763                     620                     524
# 3                      436                     340                     275
# 4                      319                     257                     181
# 5                      861                     630                     549
# 6                      540                     387                     345
# 7                     1445                    1019                     802
# 8                      233                     207                     205
# 9                      763                     783                     817
# 10                     465                     411                     375
# 11                     414                     299                     260
# 12                     436                     349                     325
# 13                     493                     430                     338
# 14                     985                     752                     652
# 15                     612                     508                     366
# 16                     788                     693                     650
# 17                     216                     165                     163
# 18                     796                     574                     462
# 19                     210                     165                     126
# 20                     427                     343                     209
# 21                     596                     442                     312
# 22                     634                     425                     292
# 23                     700                     522                     411
# 24                    1760                    1199                     762
# 25                     285                     229                     197
# 26                     247                     233                     176
# 27                     459                     379                     307
# 28                     467                     379                     311
# 29                     501                     402                     249
# ..                     ...                     ...                     ...
# 47                     546                     387                     251
# 48                    1218                     860                     644
# 49                     185                     129                      80
# 50                     321                     247                     170
# 51                     315                     298                     238
# 52                     614                     411                     259
# 53                      53                      64                      38
# 54                     198                     150                     148
# 55                     667                     585                     579
# 56                     161                     123                     125
# 57                     317                     284                     230
# 58                     160                     124                     111
# 59                     404                     355                     302
# 60                     432                     328                     228
# 61                     191                     141                     169
# 62                     270                     171                     113
# 63                     362                     326                     305
# 64                     308                     241                     250
# 65                     525                     370                     284
# 66                     686                     593                     380
# 67                     515                     457                     352
# 68                     533                     480                     486
# 69                     455                     408                     435
# 70                    1224                     999                     632
# 71                     326                     227                     193
# 72                     879                     713                     464
# 73                     244                     223                     257
# 74                     530                     425                     311
# 75                     182                     204                     169
# 76                     854                     657                     636
#
#     Female: 85 years and over  Total Households  Total Housing Units
# 0                         388             24292                27564
# 1                         931             24755                27466
# 2                         690             29719                32541
# 3                         316             18194                19906
# 4                         203             14561                16197
# 5                         780             54425                59529
# 6                         519             33536                36864
# 7                         808             51714                62364
# 8                         215              4726                 4964
# 9                        1312             14937                15848
# 10                        423             10137                11005
# 11                        306              6864                 7182
# 12                        362              6546                 7052
# 13                        391             16322                17982
# 14                        717             22804                24783
# 15                        379             20376                22420
# 16                        719             15373                16348
# 17                        204              4442                 4829
# 18                        465             21591                23634
# 19                         99              6981                 7767
# 20                        224             13573                15339
# 21                        303             29352                32486
# 22                        198             17093                20310
# 23                        448             38190                41845
# 24                        639             32792                38214
# 25                        122              5875                 8104
# 26                        164              7020                 8764
# 27                        295             26298                29813
# 28                        288             11484                14702
# 29                        226             18131                21108
# ..                        ...               ...                  ...
# 47                        193              5514                 5915
# 48                        618             15492                17875
# 49                         61              2940                 3385
# 50                        139              5187                 5705
# 51                        220              6948                 7649
# 52                        161              9492                11272
# 53                         28              2099                 2763
# 54                        152              3537                 3862
# 55                        618             11927                13106
# 56                        151              3844                 4250
# 57                        208             12187                14060
# 58                        113              4981                 5569
# 59                        284             12223                13749
# 60                        177             12680                15944
# 61                        180              4957                 5272
# 62                        163              9384                10323
# 63                        302              8467                 9074
# 64                        308              8766                 9362
# 65                        269             15557                18467
# 66                        277             10417                13422
# 67                        341             10248                14518
# 68                        544             12585                15517
# 69                        399             12451                13060
# 70                        513             17603                20351
# 71                        206              7546                 7915
# 72                        363              9482                10365
# 73                        253              6990                 7374
# 74                        456              8187                 8958
# 75                        166              6127                 6677
# 76                        691             29516                32889
#
# [77 rows x 51 columns]

# %%
gender_df = gender_df.assign(male = gender_df.filter(regex="Male", axis=1).apply(sum, axis=1),
                             female = gender_df.filter(regex="Female", axis=1).apply(sum, axis=1))


gender_long_df = gender_df.filter(regex='Geog|(^male)|female', axis=1)\
                           .melt(id_vars=['Geog', 'GeogKey'], var_name='Gender', value_name='Population')
    
gender_long_df.tail(10)
# Out:
#                        Geog  GeogKey Gender  Population
# 144               Englewood       68   male       13780
# 145  Greater Grand Crossing       69   male       14333
# 146                 Ashburn       70   male       19690
# 147          Auburn Gresham       71   male       21423
# 148                 Beverly       72   male        9558
# 149      Washington Heights       73   male       11680
# 150         Mount Greenwood       74   male        9396
# 151             Morgan Park       75   male       10208
# 152                  O'Hare       76   male        6421
# 153               Edgewater       77   male       29034

# %%
gender_agg_df = gender_long_df.groupby('Gender')['Population']\
                              .agg({'mean', 'median', 'min', 'max', 'sum'})
gender_agg_df.rename(columns={col:col+'_population' for col in gender_agg_df.columns})
# Out:
#         median_population  max_population  sum_population  mean_population  \
# Gender
# female              16310           53325         1387526     18019.818182
# male                14245           47000         1308072     16987.948052
#
#         min_population
# Gender
# female            1485
# male              1286

# %%
# TOP 10 MOST POPULOUS NEIGHBORHOODS

top_10_df = gender_long_df.groupby(['Gender'])['Population'].nlargest(10)\
              .to_frame().reset_index().set_index('level_1').rename_axis(None)

grp_df = top_10_df.join(gender_long_df[['Geog']])\
                  .pivot_table(index=['Gender'], columns=['Geog'], values='Population')

grp_df
# Out:
# Geog    Austin  Belmont Cragin  Lake View  Lincoln Park  Logan Square  \
# Gender
# female   53325           39134      47368         33686         35986
# male     45189           39609      47000         30430         36805
#
# Geog    Near North Side  Portage Park  South Lawndale  West Ridge  West Town
# Gender
# female            43147         32787           33893       36420      40178
# male              37337         31337           45395       35522      42058

# %%
import seaborn as sns

sns.set()

fig = grp_df.plot(kind='bar', edgecolor='w', figsize=(15,5), rot=0, width=0.5, fontsize = 15)

# ADD TITLES, LABELS, RE-ORIENT LEGEND
plt.title('Top Ten Chicago Community Areas By Gender', weight='bold', size=24)
plt.xlabel('Gender', weight='bold', size=24)
plt.ylabel('Population', weight='bold', size=20)
plt.legend(loc='right', ncol=5, frameon=True, shadow=False, prop={'size': 12},
           bbox_to_anchor=(0.87, -0.35))
    
plt.tight_layout()
plt.show()
plt.clf()
plt.close()

# %% [markdown]
# ***
# ## Learn when to use basic row and column transformations
# - ** Avoid inefficient, long-winded transforms needs by not knowing core methods. **
# - ** Instead, learn the direction and outcomes of procedures. **

# %% [markdown]
# ### [Reshaping and Pivot Tables](https://pandas.pydata.org/pandas-docs/stable/reshaping.html)
#
# ### HORIZONTAL
#
# 1. BY NAMED COLUMNS
#   - SINGLE DF BY COLS: `pd.merge()`
#   - MANY DFs BY COLS: `reduce(lambda x,y: merge(x, y, on='col'), df_list)`
#
# 2. BY INDEX
#   - SINGLE DF BY INDEX: `pd.join()`
#   - MANY DFs BY INDEX: `pd.concat(df_list, axis=1)`
#
# - RESHAPE (long to wide): `pd.pivot()`

# %%
# MERGE
pd.merge(demo_df.query("analysis_tool == 'pandas'"),demo_df.query("analysis_tool == 'sas'"),
         on = "database", how = "left", suffixes = ['_pd', '_sas']).head()
# Out:
#      date_pd analysis_tool_pd     num1_pd    database   num2_pd      os_pd  \
# 0 2018-01-01           pandas -147.378978         db2  0.284513     debian
# 1 2018-03-09           pandas   84.525485  sql server  0.419493  windows 7
# 2 2018-03-09           pandas   84.525485  sql server  0.419493  windows 7
# 3 2018-02-08           pandas  220.204327         db2  0.837059        ios
# 4 2018-02-25           pandas -103.699398         db2  0.461672    android
#
#    num3_pd  bool_pd   date_sas analysis_tool_sas   num1_sas  num2_sas  \
# 0       59     True        NaT               NaN        NaN       NaN
# 1       51     True 2018-03-17               sas -72.907403  0.282253
# 2       51     True 2018-03-02               sas   2.573104  0.428336
# 3       83     True        NaT               NaN        NaN       NaN
# 4       75     True        NaT               NaN        NaN       NaN
#
#        os_sas  num3_sas bool_sas
# 0         NaN       NaN      NaN
# 1   windows 7      66.0    False
# 2  windows 10      29.0    False
# 3         NaN       NaN      NaN
# 4         NaN       NaN      NaN

# %%
# JOIN
demo_df.query("analysis_tool == 'pandas'").reset_index(drop=True)\
    .join(demo_df.query("analysis_tool == 'sas'").reset_index(drop=True),
          how='inner', lsuffix='_pd', rsuffix='_sas')
# Out:
#      date_pd analysis_tool_pd     num1_pd database_pd   num2_pd      os_pd  \
# 0 2018-01-01           pandas -147.378978         db2  0.284513     debian
# 1 2018-03-09           pandas   84.525485  sql server  0.419493  windows 7
# 2 2018-02-08           pandas  220.204327         db2  0.837059        ios
# 3 2018-02-25           pandas -103.699398         db2  0.461672    android
# 4 2018-04-05           pandas  -84.472197  sql server  0.230288     ubuntu
# 5 2018-02-15           pandas  -50.845769       mysql  0.209407     mac os
# 6 2018-04-24           pandas  -58.061706       mysql  0.049702  windows 7
#
#    num3_pd  bool_pd   date_sas analysis_tool_sas    num1_sas database_sas  \
# 0       59     True 2018-03-01               sas  149.028167       sqlite
# 1       51     True 2018-03-12               sas   68.422818       sqlite
# 2       83     True 2018-02-22               sas  102.520173        mysql
# 3       75     True 2018-03-17               sas  -72.907403   sql server
# 4       25    False 2018-03-15               sas   19.871705     postgres
# 5        2     True 2018-03-02               sas    2.573104   sql server
# 6       68    False 2018-04-15               sas   66.723778     postgres
#
#    num2_sas      os_sas  num3_sas  bool_sas
# 0  0.030791     android        73      True
# 1  0.223199      ubuntu        41      True
# 2  0.613246  windows 10         5     False
# 3  0.282253   windows 7        66     False
# 4  0.208399      mac os        40     False
# 5  0.428336  windows 10        29     False
# 6  0.556798  windows 10        62      True

# %% [markdown]
# ### VERTICAL
#
# 1. SINGLE DF STACK: `pd.append()`
# 2. MANY DFs STACK: `pd.concat(df_list, axis=0)`
# 3. RESHAPE (from wide): `pd.melt()`, `pd.wide_to_long()`

# %%
# APPEND
demo_df.query("analysis_tool == 'pandas'").append(demo_df.query("analysis_tool == 'sas'"), ignore_index=True)
# Out:
#          date analysis_tool        num1    database      num2          os  \
# 0  2018-01-01        pandas -147.378978         db2  0.284513      debian
# 1  2018-03-09        pandas   84.525485  sql server  0.419493   windows 7
# 2  2018-02-08        pandas  220.204327         db2  0.837059         ios
# 3  2018-02-25        pandas -103.699398         db2  0.461672     android
# 4  2018-04-05        pandas  -84.472197  sql server  0.230288      ubuntu
# 5  2018-02-15        pandas  -50.845769       mysql  0.209407      mac os
# 6  2018-04-24        pandas  -58.061706       mysql  0.049702   windows 7
# 7  2018-05-04        pandas    1.273838      sqlite  0.344150  windows 10
# 8  2018-02-27        pandas   20.013363      sqlite  0.548549     android
# 9  2018-03-05        pandas   79.660529         db2  0.542860   windows 7
# 10 2018-03-21        pandas -194.989528       mysql  0.878259      ubuntu
# 11 2018-02-22        pandas  -61.398740      oracle  0.290208      mac os
# 12 2018-01-02        pandas -132.431026       mysql  0.346823      mac os
# 13 2018-05-17        pandas   53.714920       mysql  0.690518         ios
# 14 2018-03-01           sas  149.028167      sqlite  0.030791     android
# 15 2018-03-12           sas   68.422818      sqlite  0.223199      ubuntu
# 16 2018-02-22           sas  102.520173       mysql  0.613246  windows 10
# 17 2018-03-17           sas  -72.907403  sql server  0.282253   windows 7
# 18 2018-03-15           sas   19.871705    postgres  0.208399      mac os
# 19 2018-03-02           sas    2.573104  sql server  0.428336  windows 10
# 20 2018-04-15           sas   66.723778    postgres  0.556798  windows 10
#
#     num3   bool
# 0     59   True
# 1     51   True
# 2     83   True
# 3     75   True
# 4     25  False
# 5      2   True
# 6     68  False
# 7     54   True
# 8     37   True
# 9     87  False
# 10    13   True
# 11    64   True
# 12    80   True
# 13    11   True
# 14    73   True
# 15    41   True
# 16     5  False
# 17    66  False
# 18    40  False
# 19    29  False
# 20    62   True

# %%
# CONCAT
pd.concat([demo_df.query("analysis_tool == 'pandas'"),
           demo_df.query("analysis_tool == 'julia'"),
           demo_df.query("analysis_tool == 'sas'")], ignore_index=True)
# Out:
#          date analysis_tool        num1    database      num2          os  \
# 0  2018-01-01        pandas -147.378978         db2  0.284513      debian
# 1  2018-03-09        pandas   84.525485  sql server  0.419493   windows 7
# 2  2018-02-08        pandas  220.204327         db2  0.837059         ios
# 3  2018-02-25        pandas -103.699398         db2  0.461672     android
# 4  2018-04-05        pandas  -84.472197  sql server  0.230288      ubuntu
# 5  2018-02-15        pandas  -50.845769       mysql  0.209407      mac os
# 6  2018-04-24        pandas  -58.061706       mysql  0.049702   windows 7
# 7  2018-05-04        pandas    1.273838      sqlite  0.344150  windows 10
# 8  2018-02-27        pandas   20.013363      sqlite  0.548549     android
# 9  2018-03-05        pandas   79.660529         db2  0.542860   windows 7
# 10 2018-03-21        pandas -194.989528       mysql  0.878259      ubuntu
# 11 2018-02-22        pandas  -61.398740      oracle  0.290208      mac os
# 12 2018-01-02        pandas -132.431026       mysql  0.346823      mac os
# 13 2018-05-17        pandas   53.714920       mysql  0.690518         ios
# 14 2018-02-02         julia  -80.809133  sql server  0.802394     android
# 15 2018-05-07         julia -260.442372  sql server  0.624550   windows 7
# 16 2018-02-09         julia  124.871317  sql server  0.538567         ios
# 17 2018-01-16         julia   13.863508         db2  0.770288      ubuntu
# 18 2018-01-10         julia   14.060413    postgres  0.196518   windows 7
# 19 2018-04-12         julia  -65.547195         db2  0.506407     android
# 20 2018-03-03         julia -102.453265  sql server  0.275440     android
# 21 2018-01-28         julia  -37.389376       mysql  0.277813     android
# 22 2018-04-30         julia   63.369345    postgres  0.073218     android
# 23 2018-01-12         julia  -92.959970    postgres  0.992373         ios
# 24 2018-03-01           sas  149.028167      sqlite  0.030791     android
# 25 2018-03-12           sas   68.422818      sqlite  0.223199      ubuntu
# 26 2018-02-22           sas  102.520173       mysql  0.613246  windows 10
# 27 2018-03-17           sas  -72.907403  sql server  0.282253   windows 7
# 28 2018-03-15           sas   19.871705    postgres  0.208399      mac os
# 29 2018-03-02           sas    2.573104  sql server  0.428336  windows 10
# 30 2018-04-15           sas   66.723778    postgres  0.556798  windows 10
#
#     num3   bool
# 0     59   True
# 1     51   True
# 2     83   True
# 3     75   True
# 4     25  False
# 5      2   True
# 6     68  False
# 7     54   True
# 8     37   True
# 9     87  False
# 10    13   True
# 11    64   True
# 12    80   True
# 13    11   True
# 14    65   True
# 15    72   True
# 16    42  False
# 17    18   True
# 18    59   True
# 19    61  False
# 20    39  False
# 21     3  False
# 22    37   True
# 23    34   True
# 24    73   True
# 25    41   True
# 26     5  False
# 27    66  False
# 28    40  False
# 29    29  False
# 30    62   True

# %%
# GRAPHING PLOT
pvt_df
# Out:
# analysis_tool     julia    pandas         r       sas      spss     stata
# date
# 2018-01-31     0.440940  0.053929  0.003682  0.000000  0.141099  0.014372
# 2018-02-28     0.201378  0.164770  0.004077  0.021902  0.066352  0.000000
# 2018-03-31     0.017770  0.167304  0.185528  0.058961  0.063984  0.061679
# 2018-04-30     0.036201  0.048322  0.094860  0.074240  0.000000  0.148833
# 2018-05-31     0.129422  0.180692  0.037992  0.000000  0.000000  0.158225

# %%
# MELT
pvt_df.reset_index().melt(id_vars='date', var_name='analysis_tool', value_name='month_mean')
# Out:
#          date analysis_tool  month_mean
# 0  2018-01-31         julia    0.440940
# 1  2018-02-28         julia    0.201378
# 2  2018-03-31         julia    0.017770
# 3  2018-04-30         julia    0.036201
# 4  2018-05-31         julia    0.129422
# 5  2018-01-31        pandas    0.053929
# 6  2018-02-28        pandas    0.164770
# 7  2018-03-31        pandas    0.167304
# 8  2018-04-30        pandas    0.048322
# 9  2018-05-31        pandas    0.180692
# 10 2018-01-31             r    0.003682
# 11 2018-02-28             r    0.004077
# 12 2018-03-31             r    0.185528
# 13 2018-04-30             r    0.094860
# 14 2018-05-31             r    0.037992
# 15 2018-01-31           sas    0.000000
# 16 2018-02-28           sas    0.021902
# 17 2018-03-31           sas    0.058961
# 18 2018-04-30           sas    0.074240
# 19 2018-05-31           sas    0.000000
# 20 2018-01-31          spss    0.141099
# 21 2018-02-28          spss    0.066352
# 22 2018-03-31          spss    0.063984
# 23 2018-04-30          spss    0.000000
# 24 2018-05-31          spss    0.000000
# 25 2018-01-31         stata    0.014372
# 26 2018-02-28         stata    0.000000
# 27 2018-03-31         stata    0.061679
# 28 2018-04-30         stata    0.148833
# 29 2018-05-31         stata    0.158225

# %% [markdown]
# ***
# ## Tour current, live pandas questions
#
# ### https://stackoverflow.com/questions/tagged/pandas
